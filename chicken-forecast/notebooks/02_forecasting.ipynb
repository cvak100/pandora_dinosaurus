# %% [markdown]
# # Part 2 – Weekly Forecasting
#
# LightGBM model predicting **next week's total eggs** and a performance **score in [-1, +1]**.
#
# ```bash
# python -m src.train
# python -m src.predict
# ```

# %%
from pathlib import Path
import sys, json
import pandas as pd
from IPython.display import Markdown, display

ROOT = Path("..").resolve()
sys.path.insert(0, str(ROOT))

from src.train import train
from src.predict import predict_next_week

# %%
metrics = train()
metrics

# %%
display(Markdown((ROOT / "reports" / "forecast_eval.md").read_text(encoding="utf-8")))
predict_next_week()
